# %% [markdown]
# # ModelFlow in the browser (JupyterLite)
#
# Python runs inside your browser (Pyodide); nothing is installed on your computer.
# The first cell installs ModelFlow into the browser session. It takes a little while the
# first time and has to be run again each time the page is reloaded.
#
# To run the notebook press **run > run all cells** in the menu line

# %% [markdown]
# ## Now import ModelFlow

# %%
import sys
if sys.platform == 'emscripten':  # only in the browser (JupyterLite): install ModelFlow, see mfsetup.py
    # %run mfsetup.py
    await install_modelflow()

# %%
from modelclass import model
model.scroll_off() 
model.widescreen()
# Out:
#             <style id="mf-scroll-off">
#                 .jp-mod-outputsScrolled .jp-Cell-outputArea {
#                     max-height: none !important;
#                     height: auto !important;
#                     overflow-y: visible !important;
#                     resize: none !important;
#                 }
#                 .jp-OutputArea-output.jp-OutputArea-output { max-height: none !important; }
#                 /* Classic Notebook (<=6) sets height, not max-height, on output_scroll */
#                 .output_scroll {
#                     height: auto !important;
#                     max-height: none !important;
#                     overflow: visible !important;
#                     box-shadow: none !important;
#                 }
#             </style>
#         <style id="mf-widescreen">
#             /* Classic Notebook (<=6) */
#             div#notebook-container    { width: 95% !important; }
#             div#menubar-container     { width: 65% !important; }
#             div#maintoolbar-container { width: 99% !important; }
#
#             /* Notebook 7 / JupyterLab */
#             .jp-Notebook,
#             .jp-WindowedPanel-outer,
#             .jp-WindowedPanel-inner { max-width: none !important; }
#             .jp-Notebook .jp-Cell   { max-width: none !important; }
#             /* Some themes constrain the notebook via a centered column: */
#             .jp-NotebookPanel       { max-width: none !important; }
#         </style>

# %% [markdown]
# ## Load the Pakistan model and run the baseline

# %%
mpak,bline = model.modelload('data/pak.pcim',run=True,keep='Baseline')
# Out:
# Zipped file read:  data\pak.pcim

# %% [markdown]
# Now we got a model `mpak` and a dataframe with a baseline `bline`
#
# A **dataframe** is a matix of all variable in the model with **variables** as columns and **years** as rows.
#
# So we got all which is needed for creating experiments with the model.

# %% [markdown]
# ## Simulating the impact of imposing a carbon price
#
# A simulation follows three steps:
#
# 1. **Create a scenario DataFrame** from a baseline using `.upd()`, which applies an update expression that updates selected variables over a chosen time range.
# 2. **Solve the model** by calling it with the scenario DataFrame, a start and end year, and a `keep=` label that names the scenario for later comparison.
# 3. **Inspect results** on the returned DataFrame or directly on the model, which stores each kept scenario.

# %% [markdown]
# ### Create a scenario Dataframe

# %%
CT30df = bline.upd("<2025 2050> PAKGGREVCO2CER PAKGGREVCO2GER PAKGGREVCO2OER = 30")

# %% [markdown]
# **Breakdown**
#
#
# $$
# \begin{aligned}
# &\underbrace{\texttt{CT30df}}_{\text{scenario dataframe}}
#  = \underbrace{\texttt{bline}}_{\text{baseline dataframe}}
#  \,.\,\underbrace{\texttt{upd}}_{\text{accessor}}\bigl(\texttt{"}\ldots\texttt{"}\bigr) \\[8pt]
# &\text{where the update string is} \\[4pt]
# &\texttt{"}\,
#  \overbrace{\texttt{<2025 2050>}}^{\text{years}}\
#  \overbrace{\texttt{PAKGGREVCO2CER PAKGGREVCO2GER PAKGGREVCO2OER}}^{\text{coal, gas, oil CO}_2\text{ tax rates}}\
#  \overbrace{\texttt{=}}^{\text{set}}\
#  \overbrace{\texttt{30}}^{\text{USD/tCO}_2}
#  \,\texttt{"}
# \end{aligned}
# $$

# %% [markdown]
# ### Solve the model

# %%
resultsdf = mpak(CT30df,2020,2050,keep="Nominal $30 USD Carbon tax")

# %% [markdown]
# **Breakdown**
# $$
# \small
# \underbrace{\texttt{resultsdf}}_{\text{results df}}
# = \underbrace{\texttt{mpak}}_{\text{model}}\bigl(
# \underbrace{\texttt{CT30df}}_{\text{scenario df}},\;
# \underbrace{\texttt{2020}}_{\text{start}},\;
# \underbrace{\texttt{2050}}_{\text{end}},\;
# \underbrace{\texttt{keep="Nominal \$30USD Carbon tax"}}_{\text{scenario label}}
# \bigr)
# $$
#
# where **df** is short for **dataframe**

# %% [markdown]
# ### Inspect results
#
#  **Note**
#
#  `resultsdf` is rarely used directly. The model object `mpak` keeps the baseline (`mpak.basedf`) and the latest run (`mpak.lastdf`) internally, so the following cells can compare and plot results directly from `mpak`.
#
#  In the widget below the result for the variables `PAKNYGDPMKTPCN PAKFMLBLPOLYXN PAKCCEMISCO2?KN` can be inspected. Try selecting the different tabs.

# %%
mpak['PAKNYGDPMKTPCN PAKFMLBLPOLYXN PAKCCEMISCO2?KN']
# Out:
# Tab(children=(Tab(children=(HTML(value='<?xml version="1.0" encoding="utf-8" standalone="no"?>\n<!DOCTYPE svg …

# %% [markdown]
# ### Show impact as nice graphs

# %%
mpak['PAKNYGDPMKTPCN PAKFMLBLPOLYXN PAKCCEMISCO2?KN'].rplot(samefig=0,datatype='difpctlevel',tab=True)
# Out:
# Accordion(children=(HTML(value='<?xml version="1.0" encoding="utf-8" standalone="no"?>\n<!DOCTYPE svg PUBLIC "…

# %% [markdown]
# ### How does the different variables influence the result of a endogenous variable
# In this case the GDP, but any endogenous variable can be shown

# %%
mpak.PAKNYGDPMKTPKN.tracepre()
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.1.2 (0)
#  -->
# <!-- Title: TD Pages: 1 -->
# <svg width="432pt" height="408pt"
#  viewBox="0.00 0.00 432.00 408.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.815171 0.815171) rotate(0) translate(4 496.5)">
# <title>TD</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-496.5 525.95,-496.5 525.95,4 -4,4"/>
# <text xml:space="preserve" text-anchor="middle" x="260.98" y="-7.2" font-family="Times New Roman,serif" font-size="14.00">PAKNYGDPMKTPKN</text>
# <!-- PAKNEEXPGNFSKN -->
# <g id="node1" class="node">
# <title>PAKNEEXPGNFSKN</title>
# <g id="a_node1"><a xlink:title="Exports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEEXPGNFSKN = (PAKNEEXPGNFSKN(&#45;1)*EXP(PAKNEEXPGNFSKN_A+ (&#45;0.35*(LOG(PAKNEEXPGNFSKN(&#45;1))&#45;LOG(PAKXMKT(&#45;1))&#45;0.6*LOG(PAKNEEXPGNFSXN(&#45;1)/(PAKNYGDPFCSTXN(&#45;1))))+1*((LOG(PAKXMKT))&#45;(LOG(PAKXMKT(&#45;1))))+0.3*((LOG(PAKNEEXPGNFSXN/(PAKNYGDPFCSTXN)))&#45;(LOG(PAKNEEXPGNFSXN(&#45;1)/(PAKNYGDPFCSTXN(&#45;1)))))+4.38465374402991&#45;0.237469889780178*DURING_1999&#45;0.230689812873392*DURING_1998+0.320967524344658*DURING_1991+0.250252413901575*DURING_1986) )) * (1&#45;PAKNEEXPGNFSKN_D)+ PAKNEEXPGNFSKN_X*PAKNEEXPGNFSKN_D &#160;$">
# <polygon fill="#63b8ff" stroke="black" points="244.85,-492.5 39.75,-492.5 39.75,-456.5 244.85,-456.5 244.85,-492.5"/>
# <g id="a_node1_0"><a xlink:title="Exports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEEXPGNFSKN = (PAKNEEXPGNFSKN(&#45;1)*EXP(PAKNEEXPGNFSKN_A+ (&#45;0.35*(LOG(PAKNEEXPGNFSKN(&#45;1))&#45;LOG(PAKXMKT(&#45;1))&#45;0.6*LOG(PAKNEEXPGNFSXN(&#45;1)/(PAKNYGDPFCSTXN(&#45;1))))+1*((LOG(PAKXMKT))&#45;(LOG(PAKXMKT(&#45;1))))+0.3*((LOG(PAKNEEXPGNFSXN/(PAKNYGDPFCSTXN)))&#45;(LOG(PAKNEEXPGNFSXN(&#45;1)/(PAKNYGDPFCSTXN(&#45;1)))))+4.38465374402991&#45;0.237469889780178*DURING_1999&#45;0.230689812873392*DURING_1998+0.320967524344658*DURING_1991+0.250252413901575*DURING_1986) )) * (1&#45;PAKNEEXPGNFSKN_D)+ PAKNEEXPGNFSKN_X*PAKNEEXPGNFSKN_D &#160;$">
# <text xml:space="preserve" text-anchor="start" x="45.55" y="-469.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNEEXPGNFSKN:Exports real</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNYGDPMKTPKN -->
# <g id="node10" class="node">
# <title>PAKNYGDPMKTPKN</title>
# <g id="a_node10"><a xlink:title="Real GDP&#10;FRML &lt;IDENT&gt; PAKNYGDPMKTPKN = PAKNECONPRVTKN+PAKNECONGOVTKN+PAKNEGDIFTOTKN+PAKNEGDISTKBKN+PAKNEEXPGNFSKN&#45;PAKNEIMPGNFSKN+PAKNYGDPDISCKN+PAKADAP*PAKDISPREPKN $">
# <polygon fill="red" stroke="black" points="521.95,-276.5 320.6,-276.5 320.6,-240.5 521.95,-240.5 521.95,-276.5"/>
# <g id="a_node10_1"><a xlink:title="Real GDP&#10;FRML &lt;IDENT&gt; PAKNYGDPMKTPKN = PAKNECONPRVTKN+PAKNECONGOVTKN+PAKNEGDIFTOTKN+PAKNEGDISTKBKN+PAKNEEXPGNFSKN&#45;PAKNEIMPGNFSKN+PAKNYGDPDISCKN+PAKADAP*PAKDISPREPKN $">
# <text xml:space="preserve" text-anchor="start" x="326.4" y="-253.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNYGDPMKTPKN:Real GDP</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNEEXPGNFSKN&#45;&gt;PAKNYGDPMKTPKN -->
# <g id="edge8" class="edge">
# <title>PAKNEEXPGNFSKN&#45;&gt;PAKNYGDPMKTPKN</title>
# <g id="a_edge8"><a xlink:href="bogus" xlink:title=" PAKNEEXPGNFSKN &#45;&gt; PAKNYGDPMKTPKN Min. att. &#45;171% &#160;max: 0%">
# <path fill="none" stroke="black" stroke-width="8" d="M245.32,-464.71C259.18,-460.66 272.71,-455.1 284.6,-447.5 344.08,-409.5 385.57,-335.32 405.92,-292.05"/>
# <polygon fill="black" stroke="black" stroke-width="8" points="412.17,-295.22 409.92,-283.22 399.42,-289.45 412.17,-295.22"/>
# </a>
# </g>
# </g>
# <!-- PAKNEIMPGNFSKN -->
# <g id="node2" class="node">
# <title>PAKNEIMPGNFSKN</title>
# <g id="a_node2"><a xlink:title="Imports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEIMPGNFSKN = (PAKNEIMPGNFSKN(&#45;1)*EXP(PAKNEIMPGNFSKN_A+ (&#45;0.324143718656754*(LOG(PAKNEIMPGNFSKN(&#45;1))&#45;LOG(PAKNEGDETTOTKN(&#45;1))+0.8*LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1)))&#45;0.583459272245018+1*((LOG(PAKNEGDETTOTKN))&#45;(LOG(PAKNEGDETTOTKN(&#45;1))))&#45;0.0921874580409631*((LOG(PAKNEIMPGNFSXN/PAKNYGDPFCSTXN))&#45;(LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1))))&#45;0.0361746331863615*DURING_2012) )) * (1&#45;PAKNEIMPGNFSKN_D)+ PAKNEIMPGNFSKN_X*PAKNEIMPGNFSKN_D &#160;$">
# <polygon fill="#63b8ff" stroke="black" points="244.85,-438.5 39.75,-438.5 39.75,-402.5 244.85,-402.5 244.85,-438.5"/>
# <g id="a_node2_2"><a xlink:title="Imports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEIMPGNFSKN = (PAKNEIMPGNFSKN(&#45;1)*EXP(PAKNEIMPGNFSKN_A+ (&#45;0.324143718656754*(LOG(PAKNEIMPGNFSKN(&#45;1))&#45;LOG(PAKNEGDETTOTKN(&#45;1))+0.8*LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1)))&#45;0.583459272245018+1*((LOG(PAKNEGDETTOTKN))&#45;(LOG(PAKNEGDETTOTKN(&#45;1))))&#45;0.0921874580409631*((LOG(PAKNEIMPGNFSXN/PAKNYGDPFCSTXN))&#45;(LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1))))&#45;0.0361746331863615*DURING_2012) )) * (1&#45;PAKNEIMPGNFSKN_D)+ PAKNEIMPGNFSKN_X*PAKNEIMPGNFSKN_D &#160;$">
# <text xml:space="preserve" text-anchor="start" x="45.55" y="-415.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNEIMPGNFSKN:Imports real</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNEIMPGNFSKN&#45;&gt;PAKNYGDPMKTPKN -->
# <g id="edge4" class="edge">
# <title>PAKNEIMPGNFSKN&#45;&gt;PAKNYGDPMKTPKN</title>
# <g id="a_edge4"><a xlink:href="bogus" xlink:title=" PAKNEIMPGNFSKN &#45;&gt; PAKNYGDPMKTPKN Min. att. &#45;67% &#160;max: 2561%">
# <path fill="none" stroke="black" stroke-width="8" d="M245,-408.67C258.76,-404.91 272.34,-399.97 284.6,-393.5 331.99,-368.47 373.53,-321.39 397.77,-289.98"/>
# <polygon fill="black" stroke="black" stroke-width="8" points="403.08,-294.57 403.47,-282.37 391.87,-286.18 403.08,-294.57"/>
# </a>
# </g>
# </g>
# <!-- PAKNECONPRVTKN -->
# <g id="node3" class="node">
# <title>PAKNECONPRVTKN</title>
# <g id="a_node3"><a xlink:title="HH. Cons Real&#10;FRML &lt;DAMP,STOC&gt; PAKNECONPRVTKN = (PAKNECONPRVTKN(&#45;1)*EXP(PAKNECONPRVTKN_A+ (&#45;0.2*(LOG(PAKNECONPRVTKN(&#45;1))&#45;LOG(1.21203101101442)&#45;LOG((((PAKBXFSTREMTCD(&#45;1)&#45;PAKBMFSTREMTCD(&#45;1))*PAKPANUSATLS(&#45;1))+PAKGGEXPTRNSCN(&#45;1)+PAKNYYWBTOTLCN(&#45;1)*(1&#45;PAKGGREVDRCTXN(&#45;1)/100))/PAKNECONPRVTXN(&#45;1)))+0.763938860758873*((LOG((((PAKBXFSTREMTCD&#45;PAKBMFSTREMTCD)*PAKPANUSATLS)+PAKGGEXPTRNSCN+PAKNYYWBTOTLCN*(1&#45;PAKGGREVDRCTXN/100))/PAKNECONPRVTXN))&#45;(LOG((((PAKBXFSTREMTCD(&#45;1)&#45;PAKBMFSTREMTCD(&#45;1))*PAKPANUSATLS(&#45;1))+PAKGGEXPTRNSCN(&#45;1)+PAKNYYWBTOTLCN(&#45;1)*(1&#45;PAKGGREVDRCTXN(&#45;1)/100))/PAKNECONPRVTXN(&#45;1))))&#45;0.0634474791568939*DURING_2009&#45;0.3*(PAKFMLBLPOLYXN/100&#45;((LOG(PAKNECONPRVTXN))&#45;(LOG(PAKNECONPRVTXN(&#45;1)))))) )) * (1&#45;PAKNECONPRVTKN_D)+ PAKNECONPRVTKN_X*PAKNECONPRVTKN_D &#160;$">
# <polygon fill="#63b8ff" stroke="black" points="254.6,-384.5 30,-384.5 30,-348.5 254.6,-348.5 254.6,-384.5"/>
# <g id="a_node3_3"><a xlink:title="HH. Cons Real&#10;FRML &lt;DAMP,STOC&gt; PAKNECONPRVTKN = (PAKNECONPRVTKN(&#45;1)*EXP(PAKNECONPRVTKN_A+ (&#45;0.2*(LOG(PAKNECONPRVTKN(&#45;1))&#45;LOG(1.21203101101442)&#45;LOG((((PAKBXFSTREMTCD(&#45;1)&#45;PAKBMFSTREMTCD(&#45;1))*PAKPANUSATLS(&#45;1))+PAKGGEXPTRNSCN(&#45;1)+PAKNYYWBTOTLCN(&#45;1)*(1&#45;PAKGGREVDRCTXN(&#45;1)/100))/PAKNECONPRVTXN(&#45;1)))+0.763938860758873*((LOG((((PAKBXFSTREMTCD&#45;PAKBMFSTREMTCD)*PAKPANUSATLS)+PAKGGEXPTRNSCN+PAKNYYWBTOTLCN*(1&#45;PAKGGREVDRCTXN/100))/PAKNECONPRVTXN))&#45;(LOG((((PAKBXFSTREMTCD(&#45;1)&#45;PAKBMFSTREMTCD(&#45;1))*PAKPANUSATLS(&#45;1))+PAKGGEXPTRNSCN(&#45;1)+PAKNYYWBTOTLCN(&#45;1)*(1&#45;PAKGGREVDRCTXN(&#45;1)/100))/PAKNECONPRVTXN(&#45;1))))&#45;0.0634474791568939*DURING_2009&#45;0.3*(PAKFMLBLPOLYXN/100&#45;((LOG(PAKNECONPRVTXN))&#45;(LOG(PAKNECONPRVTXN(&#45;1)))))) )) * (1&#45;PAKNECONPRVTKN_D)+ PAKNECONPRVTKN_X*PAKNECONPRVTKN_D &#160;$">
# <text xml:space="preserve" text-an

# %% [markdown]
# #### The graph (network) can be pruned to show only variables with a max impact higher than a certain threshold

# %%
mpak.PAKNYGDPMKTPKN.tracepre(filter=20 )
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.1.2 (0)
#  -->
# <!-- Title: TD Pages: 1 -->
# <svg width="432pt" height="260pt"
#  viewBox="0.00 0.00 432.00 260.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.914867 0.914867) rotate(0) translate(4 280.5)">
# <title>TD</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-280.5 468.2,-280.5 468.2,4 -4,4"/>
# <text xml:space="preserve" text-anchor="middle" x="232.1" y="-7.2" font-family="Times New Roman,serif" font-size="14.00">PAKNYGDPMKTPKN</text>
# <!-- PAKNEEXPGNFSKN -->
# <g id="node1" class="node">
# <title>PAKNEEXPGNFSKN</title>
# <g id="a_node1"><a xlink:title="Exports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEEXPGNFSKN = (PAKNEEXPGNFSKN(&#45;1)*EXP(PAKNEEXPGNFSKN_A+ (&#45;0.35*(LOG(PAKNEEXPGNFSKN(&#45;1))&#45;LOG(PAKXMKT(&#45;1))&#45;0.6*LOG(PAKNEEXPGNFSXN(&#45;1)/(PAKNYGDPFCSTXN(&#45;1))))+1*((LOG(PAKXMKT))&#45;(LOG(PAKXMKT(&#45;1))))+0.3*((LOG(PAKNEEXPGNFSXN/(PAKNYGDPFCSTXN)))&#45;(LOG(PAKNEEXPGNFSXN(&#45;1)/(PAKNYGDPFCSTXN(&#45;1)))))+4.38465374402991&#45;0.237469889780178*DURING_1999&#45;0.230689812873392*DURING_1998+0.320967524344658*DURING_1991+0.250252413901575*DURING_1986) )) * (1&#45;PAKNEEXPGNFSKN_D)+ PAKNEEXPGNFSKN_X*PAKNEEXPGNFSKN_D &#160;$">
# <polygon fill="#63b8ff" stroke="black" points="215.98,-276.5 10.88,-276.5 10.88,-240.5 215.98,-240.5 215.98,-276.5"/>
# <g id="a_node1_0"><a xlink:title="Exports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEEXPGNFSKN = (PAKNEEXPGNFSKN(&#45;1)*EXP(PAKNEEXPGNFSKN_A+ (&#45;0.35*(LOG(PAKNEEXPGNFSKN(&#45;1))&#45;LOG(PAKXMKT(&#45;1))&#45;0.6*LOG(PAKNEEXPGNFSXN(&#45;1)/(PAKNYGDPFCSTXN(&#45;1))))+1*((LOG(PAKXMKT))&#45;(LOG(PAKXMKT(&#45;1))))+0.3*((LOG(PAKNEEXPGNFSXN/(PAKNYGDPFCSTXN)))&#45;(LOG(PAKNEEXPGNFSXN(&#45;1)/(PAKNYGDPFCSTXN(&#45;1)))))+4.38465374402991&#45;0.237469889780178*DURING_1999&#45;0.230689812873392*DURING_1998+0.320967524344658*DURING_1991+0.250252413901575*DURING_1986) )) * (1&#45;PAKNEEXPGNFSKN_D)+ PAKNEEXPGNFSKN_X*PAKNEEXPGNFSKN_D &#160;$">
# <text xml:space="preserve" text-anchor="start" x="16.68" y="-253.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNEEXPGNFSKN:Exports real</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNYGDPMKTPKN -->
# <g id="node6" class="node">
# <title>PAKNYGDPMKTPKN</title>
# <g id="a_node6"><a xlink:title="Real GDP&#10;FRML &lt;IDENT&gt; PAKNYGDPMKTPKN = PAKNECONPRVTKN+PAKNECONGOVTKN+PAKNEGDIFTOTKN+PAKNEGDISTKBKN+PAKNEEXPGNFSKN&#45;PAKNEIMPGNFSKN+PAKNYGDPDISCKN+PAKADAP*PAKDISPREPKN $">
# <polygon fill="red" stroke="black" points="464.2,-168.5 262.85,-168.5 262.85,-132.5 464.2,-132.5 464.2,-168.5"/>
# <g id="a_node6_1"><a xlink:title="Real GDP&#10;FRML &lt;IDENT&gt; PAKNYGDPMKTPKN = PAKNECONPRVTKN+PAKNECONGOVTKN+PAKNEGDIFTOTKN+PAKNEGDISTKBKN+PAKNEEXPGNFSKN&#45;PAKNEIMPGNFSKN+PAKNYGDPDISCKN+PAKADAP*PAKDISPREPKN $">
# <text xml:space="preserve" text-anchor="start" x="268.65" y="-145.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNYGDPMKTPKN:Real GDP</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNEEXPGNFSKN&#45;&gt;PAKNYGDPMKTPKN -->
# <g id="edge4" class="edge">
# <title>PAKNEEXPGNFSKN&#45;&gt;PAKNYGDPMKTPKN</title>
# <g id="a_edge4"><a xlink:href="bogus" xlink:title=" PAKNEEXPGNFSKN &#45;&gt; PAKNYGDPMKTPKN Min. att. &#45;171% &#160;max: 0%">
# <path fill="none" stroke="black" stroke-width="8" d="M202.7,-240.02C210.97,-237.48 219.14,-234.64 226.85,-231.5 261.2,-217.5 297.12,-195.69 323.36,-178.23"/>
# <polygon fill="black" stroke="black" stroke-width="8" points="327.13,-184.13 331.47,-172.72 319.26,-172.55 327.13,-184.13"/>
# </a>
# </g>
# </g>
# <!-- PAKNEIMPGNFSKN -->
# <g id="node2" class="node">
# <title>PAKNEIMPGNFSKN</title>
# <g id="a_node2"><a xlink:title="Imports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEIMPGNFSKN = (PAKNEIMPGNFSKN(&#45;1)*EXP(PAKNEIMPGNFSKN_A+ (&#45;0.324143718656754*(LOG(PAKNEIMPGNFSKN(&#45;1))&#45;LOG(PAKNEGDETTOTKN(&#45;1))+0.8*LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1)))&#45;0.583459272245018+1*((LOG(PAKNEGDETTOTKN))&#45;(LOG(PAKNEGDETTOTKN(&#45;1))))&#45;0.0921874580409631*((LOG(PAKNEIMPGNFSXN/PAKNYGDPFCSTXN))&#45;(LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1))))&#45;0.0361746331863615*DURING_2012) )) * (1&#45;PAKNEIMPGNFSKN_D)+ PAKNEIMPGNFSKN_X*PAKNEIMPGNFSKN_D &#160;$">
# <polygon fill="#63b8ff" stroke="black" points="215.98,-222.5 10.88,-222.5 10.88,-186.5 215.98,-186.5 215.98,-222.5"/>
# <g id="a_node2_2"><a xlink:title="Imports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEIMPGNFSKN = (PAKNEIMPGNFSKN(&#45;1)*EXP(PAKNEIMPGNFSKN_A+ (&#45;0.324143718656754*(LOG(PAKNEIMPGNFSKN(&#45;1))&#45;LOG(PAKNEGDETTOTKN(&#45;1))+0.8*LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1)))&#45;0.583459272245018+1*((LOG(PAKNEGDETTOTKN))&#45;(LOG(PAKNEGDETTOTKN(&#45;1))))&#45;0.0921874580409631*((LOG(PAKNEIMPGNFSXN/PAKNYGDPFCSTXN))&#45;(LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1))))&#45;0.0361746331863615*DURING_2012) )) * (1&#45;PAKNEIMPGNFSKN_D)+ PAKNEIMPGNFSKN_X*PAKNEIMPGNFSKN_D &#160;$">
# <text xml:space="preserve" text-anchor="start" x="16.68" y="-199.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNEIMPGNFSKN:Imports real</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNEIMPGNFSKN&#45;&gt;PAKNYGDPMKTPKN -->
# <g id="edge2" class="edge">
# <title>PAKNEIMPGNFSKN&#45;&gt;PAKNYGDPMKTPKN</title>
# <g id="a_edge2"><a xlink:href="bogus" xlink:title=" PAKNEIMPGNFSKN &#45;&gt; PAKNYGDPMKTPKN Min. att. &#45;67% &#160;max: 2561%">
# <path fill="none" stroke="black" stroke-width="8" d="M199.11,-186.07C219.16,-181.7 240.74,-177.01 261.44,-172.5"/>
# <polygon fill="black" stroke="black" stroke-width="8" points="262.7,-179.39 270.98,-170.42 259.72,-165.71 262.7,-179.39"/>
# </a>
# </g>
# </g>
# <!-- PAKNECONPRVTKN -->
# <g id="node3" class="node">
# <title>PAKNECONPRVTKN</title>
# <g id="a_node3"><a xlink:title="HH. Cons Real&#10;FRML &lt;DAMP,STOC&gt; PAKNECONPRVTKN = (PAKNECONPRVTKN(&#45;1)*EXP(PAKNECONPRVTKN_A+ (&#45;0.2*(LOG(PAKNECONPRVTKN(&#45;1))&#45;LOG(1.21203101101442)&#45;LOG((((PAKBXFSTREMTCD(&#45;1)&#45;PAKBMFSTREMTCD(&#45;1))*PAKPANUSATLS(&#45;1))+PAKGGEXPTRNSCN(&#45;1)+PAKNYYWBTOTLCN(&#45;1)*(1&#45;PAKGGREVDRCTXN(&#45;1)/100))/PAKNECONPRVTXN(&#45;1)))+0.763938860758873*((LOG((((PAKBXFSTREMTCD&#45;PAKBMFSTREMTCD)*PAKPANUSATLS)+PAKGGEXPTRNSCN+PAKNYYWBTOTLCN*(1&#45;PAKGGREVDRCTXN/100))/PAKNECONPRVTXN))&#45;(LOG((((PAKBXFSTREMTCD(&#45;1)&#45;PAKBMFSTREMTCD(&#45;1))*PAKPANUSATLS(&#45;1))+PAKGGEXPTRNSCN(&#45;1)+PAKNYYWBTOTLCN(&#45;1)*(1&#45;PAKGGREVDRCTXN(&#45;1)/100))/PAKNECONPRVTXN(&#45;1))))&#45;0.0634474791568939*DURING_2009&#45;0.3*(PAKFMLBLPOLYXN/100&#45;((LOG(PAKNECONPRVTXN))&#45;(LOG(PAKNECONPRVTXN(&#45;1)))))) )) * (1&#45;PAKNECONPRVTKN_D)+ PAKNECONPRVTKN_X*PAKNECONPRVTKN_D &#160;$">
# <polygon fill="#63b8ff" stroke="black" points="225.73,-168.5 1.12,-168.5 1.12,-132.5 225.73,-132.5 225.73,-168.5"/>
# <g id="a_node3_3"><a xlink:title="HH. Cons Real&#10;FRML &lt;DAMP,STOC&gt; PAKNECONPRVTKN = (PAKNECONPRVTKN(&#45;1)*EXP(PAKNECONPRVTKN_A+ (&#45;0.2*(LOG(PAKNECONPRVTKN(&#45;1))&#45;LOG(1.21203101101442)&#45;LOG((((PAKBXFSTREMTCD(&#45;1)&#45;PAKBMFSTREMTCD(&#45;1))*PAKPANUSATLS(&#45;1))+PAKGGEXPTRNSCN(&#45;1)+PAKNYYWBTOTLCN(&#45;1)*(1&#45;PAKGGREVDRCTXN(&#45;1)/100))/PAKNECONPRVTXN(&#45;1)))+0.763938860758873*((LOG((((PAKBXFSTREMTCD&#45;PAKBMFSTREMTCD)*PAKPANUSATLS)+PAKGGEXPTRNSCN+PAKNYYWBTOTLCN*(1&#45;PAKGGREVDRCTXN/100))/PAKNECONPRVTXN))&#45;(LOG((((PAKBXFSTREMTCD(&#45;1)&#45;PAKBMFSTREMTCD(&#45;1))*PAKPANUSATLS(&#45;1))+PAKGGEXPTRNSCN(&#45;1)+PAKNYYWBTOTLCN(&#45;1)*(1&#45;PAKGGREVDRCTXN(&#45;1)/100))/PAKNECONPRVTXN(&#45;1))))&#45;0.0634474791568939*DURING_2009&#45;0.3*(PAKFMLBLPOLYXN/100&#45;((LOG(PAKNECONPRVTXN))&#45;(LOG(PAKNECONPRVTXN(&#45;1)))))) )) * (1&#45;PAKNECONPRVTKN_D)+ PAKNECONPRVTKN_X*PAKNECONPRVTKN_D &#160;$">
# <text xml:space="preserve" text-anchor="start" x="6.93" y="-145.45" font-fami

# %% [markdown]
# #### and we can go several levels upstream
# The filter=20 prunes the graph as it can be large

# %%
mpak.PAKNYGDPMKTPKN.tracepre(filter=20,up=2)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.1.2 (0)
#  -->
# <!-- Title: TD Pages: 1 -->
# <svg width="432pt" height="243pt"
#  viewBox="0.00 0.00 432.00 243.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.438668 0.438668) rotate(0) translate(4 550.5)">
# <title>TD</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-550.5 980.8,-550.5 980.8,4 -4,4"/>
# <text xml:space="preserve" text-anchor="middle" x="488.4" y="-7.2" font-family="Times New Roman,serif" font-size="14.00">PAKNYGDPMKTPKN</text>
# <!-- PAKNEIMPGNFSXN -->
# <g id="node1" class="node">
# <title>PAKNEIMPGNFSXN</title>
# <g id="a_node1"><a xlink:title="Imp., GNFS (NIA), LCU Price defl. 2000 = 1&#10;FRML &lt;IDENT&gt; PAKNEIMPGNFSXN = ((PAKNEIMPENGYSH**PAKCESENGYIMPT)*PAKNVENGNIMPXN**(1&#45;PAKCESENGYIMPT)+(PAKNEIMPOTHRSH**PAKCESENGYIMPT)*PAKNEIMPGSNEXN**(1&#45;PAKCESENGYIMPT))**(1/(1&#45;PAKCESENGYIMPT)) $">
# <polygon fill="#63b8ff" stroke="black" points="433.85,-546.5 42.75,-546.5 42.75,-510.5 433.85,-510.5 433.85,-546.5"/>
# <g id="a_node1_0"><a xlink:title="Imp., GNFS (NIA), LCU Price defl. 2000 = 1&#10;FRML &lt;IDENT&gt; PAKNEIMPGNFSXN = ((PAKNEIMPENGYSH**PAKCESENGYIMPT)*PAKNVENGNIMPXN**(1&#45;PAKCESENGYIMPT)+(PAKNEIMPOTHRSH**PAKCESENGYIMPT)*PAKNEIMPGSNEXN**(1&#45;PAKCESENGYIMPT))**(1/(1&#45;PAKCESENGYIMPT)) $">
# <text xml:space="preserve" text-anchor="start" x="48.55" y="-523.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNEIMPGNFSXN:Imp., GNFS (NIA), LCU Price defl. 2000 = 1</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNEIMPGNFSKN -->
# <g id="node3" class="node">
# <title>PAKNEIMPGNFSKN</title>
# <g id="a_node3"><a xlink:title="Imports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEIMPGNFSKN = (PAKNEIMPGNFSKN(&#45;1)*EXP(PAKNEIMPGNFSKN_A+ (&#45;0.324143718656754*(LOG(PAKNEIMPGNFSKN(&#45;1))&#45;LOG(PAKNEGDETTOTKN(&#45;1))+0.8*LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1)))&#45;0.583459272245018+1*((LOG(PAKNEGDETTOTKN))&#45;(LOG(PAKNEGDETTOTKN(&#45;1))))&#45;0.0921874580409631*((LOG(PAKNEIMPGNFSXN/PAKNYGDPFCSTXN))&#45;(LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1))))&#45;0.0361746331863615*DURING_2012) )) * (1&#45;PAKNEIMPGNFSKN_D)+ PAKNEIMPGNFSKN_X*PAKNEIMPGNFSKN_D &#160;$">
# <polygon fill="#63b8ff" stroke="black" points="728.57,-465.5 523.48,-465.5 523.48,-429.5 728.57,-429.5 728.57,-465.5"/>
# <g id="a_node3_1"><a xlink:title="Imports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEIMPGNFSKN = (PAKNEIMPGNFSKN(&#45;1)*EXP(PAKNEIMPGNFSKN_A+ (&#45;0.324143718656754*(LOG(PAKNEIMPGNFSKN(&#45;1))&#45;LOG(PAKNEGDETTOTKN(&#45;1))+0.8*LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1)))&#45;0.583459272245018+1*((LOG(PAKNEGDETTOTKN))&#45;(LOG(PAKNEGDETTOTKN(&#45;1))))&#45;0.0921874580409631*((LOG(PAKNEIMPGNFSXN/PAKNYGDPFCSTXN))&#45;(LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1))))&#45;0.0361746331863615*DURING_2012) )) * (1&#45;PAKNEIMPGNFSKN_D)+ PAKNEIMPGNFSKN_X*PAKNEIMPGNFSKN_D &#160;$">
# <text xml:space="preserve" text-anchor="start" x="529.27" y="-442.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNEIMPGNFSKN:Imports real</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNEIMPGNFSXN&#45;&gt;PAKNEIMPGNFSKN -->
# <g id="edge3" class="edge">
# <title>PAKNEIMPGNFSXN&#45;&gt;PAKNEIMPGNFSKN</title>
# <g id="a_edge3"><a xlink:href="bogus" xlink:title=" PAKNEIMPGNFSXN &#45;&gt; PAKNEIMPGNFSKN Min. att. 0% &#160;max: 341%">
# <path fill="none" stroke="black" stroke-width="8" d="M434.2,-510.09C448.61,-507.58 462.88,-504.73 476.6,-501.5 507.14,-494.31 540.02,-482.77 567.06,-472.19"/>
# <polygon fill="black" stroke="black" stroke-width="8" points="569.49,-478.76 576.18,-468.54 564.29,-465.76 569.49,-478.76"/>
# </a>
# </g>
# </g>
# <!-- PAKNEEXPGNFSKN -->
# <g id="node2" class="node">
# <title>PAKNEEXPGNFSKN</title>
# <g id="a_node2"><a xlink:title="Exports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEEXPGNFSKN = (PAKNEEXPGNFSKN(&#45;1)*EXP(PAKNEEXPGNFSKN_A+ (&#45;0.35*(LOG(PAKNEEXPGNFSKN(&#45;1))&#45;LOG(PAKXMKT(&#45;1))&#45;0.6*LOG(PAKNEEXPGNFSXN(&#45;1)/(PAKNYGDPFCSTXN(&#45;1))))+1*((LOG(PAKXMKT))&#45;(LOG(PAKXMKT(&#45;1))))+0.3*((LOG(PAKNEEXPGNFSXN/(PAKNYGDPFCSTXN)))&#45;(LOG(PAKNEEXPGNFSXN(&#45;1)/(PAKNYGDPFCSTXN(&#45;1)))))+4.38465374402991&#45;0.237469889780178*DURING_1999&#45;0.230689812873392*DURING_1998+0.320967524344658*DURING_1991+0.250252413901575*DURING_1986) )) * (1&#45;PAKNEEXPGNFSKN_D)+ PAKNEEXPGNFSKN_X*PAKNEEXPGNFSKN_D &#160;$">
# <polygon fill="#63b8ff" stroke="black" points="728.57,-384.5 523.48,-384.5 523.48,-348.5 728.57,-348.5 728.57,-384.5"/>
# <g id="a_node2_2"><a xlink:title="Exports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEEXPGNFSKN = (PAKNEEXPGNFSKN(&#45;1)*EXP(PAKNEEXPGNFSKN_A+ (&#45;0.35*(LOG(PAKNEEXPGNFSKN(&#45;1))&#45;LOG(PAKXMKT(&#45;1))&#45;0.6*LOG(PAKNEEXPGNFSXN(&#45;1)/(PAKNYGDPFCSTXN(&#45;1))))+1*((LOG(PAKXMKT))&#45;(LOG(PAKXMKT(&#45;1))))+0.3*((LOG(PAKNEEXPGNFSXN/(PAKNYGDPFCSTXN)))&#45;(LOG(PAKNEEXPGNFSXN(&#45;1)/(PAKNYGDPFCSTXN(&#45;1)))))+4.38465374402991&#45;0.237469889780178*DURING_1999&#45;0.230689812873392*DURING_1998+0.320967524344658*DURING_1991+0.250252413901575*DURING_1986) )) * (1&#45;PAKNEEXPGNFSKN_D)+ PAKNEEXPGNFSKN_X*PAKNEEXPGNFSKN_D &#160;$">
# <text xml:space="preserve" text-anchor="start" x="529.27" y="-361.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNEEXPGNFSKN:Exports real</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNYGDPMKTPKN -->
# <g id="node15" class="node">
# <title>PAKNYGDPMKTPKN</title>
# <g id="a_node15"><a xlink:title="Real GDP&#10;FRML &lt;IDENT&gt; PAKNYGDPMKTPKN = PAKNECONPRVTKN+PAKNECONGOVTKN+PAKNEGDIFTOTKN+PAKNEGDISTKBKN+PAKNEEXPGNFSKN&#45;PAKNEIMPGNFSKN+PAKNYGDPDISCKN+PAKADAP*PAKDISPREPKN $">
# <polygon fill="red" stroke="black" points="976.8,-303.5 775.45,-303.5 775.45,-267.5 976.8,-267.5 976.8,-303.5"/>
# <g id="a_node15_3"><a xlink:title="Real GDP&#10;FRML &lt;IDENT&gt; PAKNYGDPMKTPKN = PAKNECONPRVTKN+PAKNECONGOVTKN+PAKNEGDIFTOTKN+PAKNEGDISTKBKN+PAKNEEXPGNFSKN&#45;PAKNEIMPGNFSKN+PAKNYGDPDISCKN+PAKADAP*PAKDISPREPKN $">
# <text xml:space="preserve" text-anchor="start" x="781.25" y="-280.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNYGDPMKTPKN:Real GDP</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNEEXPGNFSKN&#45;&gt;PAKNYGDPMKTPKN -->
# <g id="edge12" class="edge">
# <title>PAKNEEXPGNFSKN&#45;&gt;PAKNYGDPMKTPKN</title>
# <g id="a_edge12"><a xlink:href="bogus" xlink:title=" PAKNEEXPGNFSKN &#45;&gt; PAKNYGDPMKTPKN Min. att. &#45;171% &#160;max: 0%">
# <path fill="none" stroke="black" stroke-width="8" d="M683.63,-348.02C718.97,-336.48 764.79,-321.52 802.75,-309.13"/>
# <polygon fill="black" stroke="black" stroke-width="8" points="804.8,-315.82 812.13,-306.07 800.45,-302.52 804.8,-315.82"/>
# </a>
# </g>
# </g>
# <!-- PAKNEIMPGNFSKN&#45;&gt;PAKNYGDPMKTPKN -->
# <g id="edge5" class="edge">
# <title>PAKNEIMPGNFSKN&#45;&gt;PAKNYGDPMKTPKN</title>
# <g id="a_edge5"><a xlink:href="bogus" xlink:title=" PAKNEIMPGNFSKN &#45;&gt; PAKNYGDPMKTPKN Min. att. &#45;67% &#160;max: 2561%">
# <path fill="none" stroke="black" stroke-width="8" d="M671.21,-429.05C692.44,-419.5 717.89,-407.02 739.45,-393.5 776.81,-370.08 815.83,-338.1 842.39,-315.03"/>
# <polygon fill="black" stroke="black" stroke-width="8" points="846.95,-320.34 849.82,-308.48 837.69,-309.83 846.95,-320.34"/>
# </a>
# </g>
# </g>
# <!-- PAKNECONPRVTKN -->
# <g id="node4" class="node">
# <title>PAKNECONPRVTKN</title>
# <g id="a_node4"><a xlink:title="HH. Cons Real&#10;FRML &lt;DAMP,STOC&gt; PAKNECONPRVTKN = (PAKNECONPRVTKN(&#45;1)*EXP(PAKNECONPRVTKN_A+ (&#45;0.2*(LOG(PAKNECONPRVTKN(&#45;1))&#45;LOG(1.21203101101442)&#45;LOG((((PAKBXFSTREMTCD(&#45;1)&#45;PAKBMFSTREMTCD(&#45;1))*PAKPANUSATLS(&#45;1))+PAKGGEXPTRNSCN(&#45;1)+PAKNYYWBTOTLCN(&#45;1)*(1&#45;PAKGGREVDRCTXN(&#45;1)/100))/PAKNECONPRVTXN(&#45;1)))+0.763938860758873*((LOG((((PAKBXFSTREMTCD&#45;PAKBMFSTREMTCD)*PAKPANUSATLS)+PAKGGEXPTRNSCN+PAKNYYWBTOT

# %% [markdown]
# ### Attribution
# Try select different years

# %%
mpak.get_dekom_gui('PAKNYGDPMKTPKN')
# Out:
# interactive(children=(Dropdown(description='Variable', index=321, options=('CHNEXR05', 'CHNPCEXN05', 'DEUEXR05…

# %% [markdown]
# ## Try some of the other notebooks in this example
# Below a list of  notebooks which can be started by clicking.

# %%
mpak.display_toc_this(text='**Try one of these notebooks**')
# Out:
# **Try one of these notebooks**
# <table style="border-collapse:collapse;border:none"><tr><td style="text-align:left;padding:2px 24px 2px 12px;white-space:nowrap"><a href="model specification.ipynb" target="_blank">model specification</a></td><td style="text-align:left;padding:2px 12px"></td></tr><tr><td style="text-align:left;padding:2px 24px 2px 12px;white-space:nowrap"><a href="modelflow_stability_examples.ipynb" target="_blank">modelflow_stability_examples</a></td><td style="text-align:left;padding:2px 12px">Stability in practice: a multiplier-accelerator model</td></tr><tr><td style="text-align:left;padding:2px 24px 2px 12px;white-space:nowrap"><a href="oldstart.ipynb" target="_blank">oldstart</a></td><td style="text-align:left;padding:2px 12px">ModelFlow in the browser (JupyterLite)</td></tr><tr><td style="text-align:left;padding:2px 24px 2px 12px;white-space:nowrap"><a href="start.ipynb" target="_blank">start</a></td><td style="text-align:left;padding:2px 12px">ModelFlow in the browser (JupyterLite)</td></tr></table>
