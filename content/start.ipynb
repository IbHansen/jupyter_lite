# %% [markdown]
# # ModelFlow in the browser (JupyterLite)
#
# Python runs inside your browser (Pyodide); nothing is installed on your computer.
# The first cell installs ModelFlow into the browser session. It takes a little while the
# first time and has to be run again each time the page is reloaded.

# %% [markdown]
# ## Now import ModelFlow

# %%
import sys
if sys.platform == 'emscripten':  # only in the browser (JupyterLite): install ModelFlow, see mfsetup.py
    # %run mfsetup.py
    await install_modelflow()

# %%
from modelclass import model

# %% [markdown]
# ## Load the Pakistan model and run the baseline

# %%
mpak,bline = model.modelload('data/pak.pcim',run=True,keep='Baseline')
# Out:
# Zipped file read:  data\pak.pcim
# The feedback variables are not directly connected, so the feedback order is left as found

# %% [markdown]
# Now we got a model `mpak` and a dataframe with a baseline `bline`
#
# A **dataframe** is a matix of all variable in the model with **variables** as columns and **years** as rows.
#
# So we got all which is needed for creating experiments with the model.

# %% [markdown]
# ## Simulating the impact of imposing a carbon price
#
# A simulation follows three steps:
#
# 1. **Create a scenario DataFrame** from a baseline using `.upd()`, which applies an update expression that updates selected variables over a chosen time range.
# 2. **Solve the model** by calling it with the scenario DataFrame, a start and end year, and a `keep=` label that names the scenario for later comparison.
# 3. **Inspect results** on the returned DataFrame or directly on the model, which stores each kept scenario.

# %% [markdown]
# ### Create a scenario Dataframe

# %%
CT30df = bline.upd("<2025 2050> PAKGGREVCO2CER PAKGGREVCO2GER PAKGGREVCO2OER = 30")

# %% [markdown]
# **Breakdown**
#
#
# $$
# \begin{aligned}
# &\underbrace{\texttt{CT30df}}_{\text{scenario dataframe}}
#  = \underbrace{\texttt{bline}}_{\text{baseline dataframe}}
#  \,.\,\underbrace{\texttt{upd}}_{\text{accessor}}\bigl(\texttt{"}\ldots\texttt{"}\bigr) \\[8pt]
# &\text{where the update string is} \\[4pt]
# &\texttt{"}\,
#  \overbrace{\texttt{<2025 2050>}}^{\text{years}}\
#  \overbrace{\texttt{PAKGGREVCO2CER PAKGGREVCO2GER PAKGGREVCO2OER}}^{\text{coal, gas, oil CO}_2\text{ tax rates}}\
#  \overbrace{\texttt{=}}^{\text{set}}\
#  \overbrace{\texttt{30}}^{\text{USD/tCO}_2}
#  \,\texttt{"}
# \end{aligned}
# $$

# %% [markdown]
# ### Solve the model

# %%
resultsdf = mpak(CT30df,2020,2050,keep="Nominal $30 USD Carbon tax")

# %% [markdown]
# **Breakdown**
# $$
# \small
# \underbrace{\texttt{resultsdf}}_{\text{results df}}
# = \underbrace{\texttt{mpak}}_{\text{model}}\bigl(
# \underbrace{\texttt{CT30df}}_{\text{scenario df}},\;
# \underbrace{\texttt{2020}}_{\text{start}},\;
# \underbrace{\texttt{2050}}_{\text{end}},\;
# \underbrace{\texttt{keep="Nominal \$30USD Carbon tax"}}_{\text{scenario label}}
# \bigr)
# $$
#
# where **df** is short for **dataframe**

# %% [markdown]
# ### Inspect results
#
#  **Note**
#
#  `resultsdf` is rarely used directly. The model object `mpak` keeps the baseline (`mpak.basedf`) and the latest run (`mpak.lastdf`) internally, so the following cells can compare and plot results directly from `mpak`.
#
#  In the widget below the result for the variables `PAKNYGDPMKTPCN PAKFMLBLPOLYXN PAKCCEMISCO2?KN` can be inspected. Try selecting the different tabs.

# %%
mpak['PAKNYGDPMKTPCN PAKFMLBLPOLYXN PAKCCEMISCO2?KN']
# Out:
# Tab(children=(Tab(children=(HTML(value='<?xml version="1.0" encoding="utf-8" standalone="no"?>\n<!DOCTYPE svg …

# %% [markdown]
# ### Show impact as nice graphs

# %%
mpak['PAKNYGDPMKTPCN PAKFMLBLPOLYXN PAKCCEMISCO2?KN'].rplot(samefig=0,datatype='difpctlevel',tab=True)
# Out:
# Accordion(children=(HTML(value='<?xml version="1.0" encoding="utf-8" standalone="no"?>\n<!DOCTYPE svg PUBLIC "…

# %% [markdown]
# ### How does the different variables influence the result of a endogenous variable
# In this case the GDP, but any endogenous variable can be shown

# %%
mpak.PAKNYGDPMKTPKN.tracepre()
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.1.2 (0)
#  -->
# <!-- Title: TD Pages: 1 -->
# <svg width="432pt" height="408pt"
#  viewBox="0.00 0.00 432.00 408.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.815171 0.815171) rotate(0) translate(4 496.5)">
# <title>TD</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-496.5 525.95,-496.5 525.95,4 -4,4"/>
# <text xml:space="preserve" text-anchor="middle" x="260.98" y="-7.2" font-family="Times New Roman,serif" font-size="14.00">PAKNYGDPMKTPKN</text>
# <!-- PAKNECONGOVTKN -->
# <g id="node1" class="node">
# <title>PAKNECONGOVTKN</title>
# <g id="a_node1"><a xlink:title="Gov. Cons real&#10;FRML &lt;IDENT&gt; PAKNECONGOVTKN = PAKNECONGOVTCN/PAKNECONGOVTXN $">
# <polygon fill="#63b8ff" stroke="black" points="255.73,-492.5 28.88,-492.5 28.88,-456.5 255.73,-456.5 255.73,-492.5"/>
# <g id="a_node1_0"><a xlink:title="Gov. Cons real&#10;FRML &lt;IDENT&gt; PAKNECONGOVTKN = PAKNECONGOVTCN/PAKNECONGOVTXN $">
# <text xml:space="preserve" text-anchor="start" x="34.68" y="-469.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNECONGOVTKN:Gov. Cons real</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNYGDPMKTPKN -->
# <g id="node7" class="node">
# <title>PAKNYGDPMKTPKN</title>
# <g id="a_node7"><a xlink:title="Real GDP&#10;FRML &lt;IDENT&gt; PAKNYGDPMKTPKN = PAKNECONPRVTKN+PAKNECONGOVTKN+PAKNEGDIFTOTKN+PAKNEGDISTKBKN+PAKNEEXPGNFSKN&#45;PAKNEIMPGNFSKN+PAKNYGDPDISCKN+PAKADAP*PAKDISPREPKN $">
# <polygon fill="red" stroke="black" points="521.95,-276.5 320.6,-276.5 320.6,-240.5 521.95,-240.5 521.95,-276.5"/>
# <g id="a_node7_1"><a xlink:title="Real GDP&#10;FRML &lt;IDENT&gt; PAKNYGDPMKTPKN = PAKNECONPRVTKN+PAKNECONGOVTKN+PAKNEGDIFTOTKN+PAKNEGDISTKBKN+PAKNEEXPGNFSKN&#45;PAKNEIMPGNFSKN+PAKNYGDPDISCKN+PAKADAP*PAKDISPREPKN $">
# <text xml:space="preserve" text-anchor="start" x="326.4" y="-253.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNYGDPMKTPKN:Real GDP</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNECONGOVTKN&#45;&gt;PAKNYGDPMKTPKN -->
# <g id="edge4" class="edge">
# <title>PAKNECONGOVTKN&#45;&gt;PAKNYGDPMKTPKN</title>
# <g id="a_edge4"><a xlink:href="bogus" xlink:title=" PAKNECONGOVTKN &#45;&gt; PAKNYGDPMKTPKN Min. att. 0% &#160;max: 2223%">
# <path fill="none" stroke="black" stroke-width="8" d="M255.91,-461.28C266.02,-457.67 275.76,-453.15 284.6,-447.5 344.08,-409.5 385.57,-335.32 405.92,-292.05"/>
# <polygon fill="black" stroke="black" stroke-width="8" points="412.17,-295.22 409.92,-283.22 399.42,-289.45 412.17,-295.22"/>
# </a>
# </g>
# </g>
# <!-- PAKADAP -->
# <g id="node2" class="node">
# <title>PAKADAP</title>
# <g id="a_node2"><a xlink:title="PAKADAP&#10;Exogen">
# <polygon fill="yellow" stroke="black" points="181.48,-438.5 103.13,-438.5 103.13,-402.5 181.48,-402.5 181.48,-438.5"/>
# <g id="a_node2_2"><a xlink:title="PAKADAP&#10;Exogen">
# <text xml:space="preserve" text-anchor="start" x="108.93" y="-415.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKADAP:</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKADAP&#45;&gt;PAKNYGDPMKTPKN -->
# <g id="edge8" class="edge">
# <title>PAKADAP&#45;&gt;PAKNYGDPMKTPKN</title>
# <g id="a_edge8"><a xlink:href="bogus" xlink:title=" PAKADAP &#45;&gt; PAKNYGDPMKTPKN Min. att. 0% &#160;max: 0%">
# <path fill="none" stroke="black" d="M181.9,-419.21C211.5,-416.83 252.58,-410.41 284.6,-393.5 334.13,-367.34 377.26,-317.1 400.94,-285.83"/>
# <polygon fill="black" stroke="black" points="403.6,-288.12 406.75,-278 397.98,-283.95 403.6,-288.12"/>
# </a>
# </g>
# </g>
# <!-- PAKNYGDPDISCKN -->
# <g id="node3" class="node">
# <title>PAKNYGDPDISCKN</title>
# <g id="a_node3"><a xlink:title="GDP Disc., 2000 LCU mn&#10;Exogen">
# <polygon fill="yellow" stroke="black" points="284.6,-384.5 0,-384.5 0,-348.5 284.6,-348.5 284.6,-384.5"/>
# <g id="a_node3_3"><a xlink:title="GDP Disc., 2000 LCU mn&#10;Exogen">
# <text xml:space="preserve" text-anchor="start" x="5.8" y="-361.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNYGDPDISCKN:GDP Disc., 2000 LCU mn</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNYGDPDISCKN&#45;&gt;PAKNYGDPMKTPKN -->
# <g id="edge1" class="edge">
# <title>PAKNYGDPDISCKN&#45;&gt;PAKNYGDPMKTPKN</title>
# <g id="a_edge1"><a xlink:href="bogus" xlink:title=" PAKNYGDPDISCKN &#45;&gt; PAKNYGDPMKTPKN Min. att. 0% &#160;max: 0%">
# <path fill="none" stroke="black" d="M258.38,-348.03C267.36,-345.53 276.2,-342.7 284.6,-339.5 321.59,-325.43 359.99,-301.49 386.45,-283.27"/>
# <polygon fill="black" stroke="black" points="388.2,-286.32 394.39,-277.72 384.19,-280.58 388.2,-286.32"/>
# </a>
# </g>
# </g>
# <!-- PAKNEIMPGNFSKN -->
# <g id="node4" class="node">
# <title>PAKNEIMPGNFSKN</title>
# <g id="a_node4"><a xlink:title="Imports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEIMPGNFSKN = (PAKNEIMPGNFSKN(&#45;1)*EXP(PAKNEIMPGNFSKN_A+ (&#45;0.324143718656754*(LOG(PAKNEIMPGNFSKN(&#45;1))&#45;LOG(PAKNEGDETTOTKN(&#45;1))+0.8*LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1)))&#45;0.583459272245018+1*((LOG(PAKNEGDETTOTKN))&#45;(LOG(PAKNEGDETTOTKN(&#45;1))))&#45;0.0921874580409631*((LOG(PAKNEIMPGNFSXN/PAKNYGDPFCSTXN))&#45;(LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1))))&#45;0.0361746331863615*DURING_2012) )) * (1&#45;PAKNEIMPGNFSKN_D)+ PAKNEIMPGNFSKN_X*PAKNEIMPGNFSKN_D &#160;$">
# <polygon fill="#63b8ff" stroke="black" points="244.85,-330.5 39.75,-330.5 39.75,-294.5 244.85,-294.5 244.85,-330.5"/>
# <g id="a_node4_4"><a xlink:title="Imports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEIMPGNFSKN = (PAKNEIMPGNFSKN(&#45;1)*EXP(PAKNEIMPGNFSKN_A+ (&#45;0.324143718656754*(LOG(PAKNEIMPGNFSKN(&#45;1))&#45;LOG(PAKNEGDETTOTKN(&#45;1))+0.8*LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1)))&#45;0.583459272245018+1*((LOG(PAKNEGDETTOTKN))&#45;(LOG(PAKNEGDETTOTKN(&#45;1))))&#45;0.0921874580409631*((LOG(PAKNEIMPGNFSXN/PAKNYGDPFCSTXN))&#45;(LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1))))&#45;0.0361746331863615*DURING_2012) )) * (1&#45;PAKNEIMPGNFSKN_D)+ PAKNEIMPGNFSKN_X*PAKNEIMPGNFSKN_D &#160;$">
# <text xml:space="preserve" text-anchor="start" x="45.55" y="-307.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNEIMPGNFSKN:Imports real</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNEIMPGNFSKN&#45;&gt;PAKNYGDPMKTPKN -->
# <g id="edge5" class="edge">
# <title>PAKNEIMPGNFSKN&#45;&gt;PAKNYGDPMKTPKN</title>
# <g id="a_edge5"><a xlink:href="bogus" xlink:title=" PAKNEIMPGNFSKN &#45;&gt; PAKNYGDPMKTPKN Min. att. &#45;56% &#160;max: 2561%">
# <path fill="none" stroke="black" stroke-width="8" d="M240.61,-294.01C255.35,-291.18 270.38,-288.27 284.6,-285.5 293.37,-283.79 302.45,-282.01 311.57,-280.21"/>
# <polygon fill="black" stroke="black" stroke-width="8" points="312.68,-287.13 321.13,-278.32 309.96,-273.39 312.68,-287.13"/>
# </a>
# </g>
# </g>
# <!-- PAKNEEXPGNFSKN -->
# <g id="node5" class="node">
# <title>PAKNEEXPGNFSKN</title>
# <g id="a_node5"><a xlink:title="Exports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEEXPGNFSKN = (PAKNEEXPGNFSKN(&#45;1)*EXP(PAKNEEXPGNFSKN_A+ (&#45;0.35*(LOG(PAKNEEXPGNFSKN(&#45;1))&#45;LOG(PAKXMKT(&#45;1))&#45;0.6*LOG(PAKNEEXPGNFSXN(&#45;1)/(PAKNYGDPFCSTXN(&#45;1))))+1*((LOG(PAKXMKT))&#45;(LOG(PAKXMKT(&#45;1))))+0.3*((LOG(PAKNEEXPGNFSXN/(PAKNYGDPFCSTXN)))&#45;(LOG(PAKNEEXPGNFSXN(&#45;1)/(PAKNYGDPFCSTXN(&#45;1)))))+4.38465374402991&#45;0.237469889780178*DURING_1999&#45;0.230689812873392*DURING_1998+0.320967524344658*DURING_1991+0.250252413901575*DURING_1986) )) * (1&#45;PAKNEEXPGNFSKN_D)+ PAKNEEXPGNFSKN_X*PAKNEEXPGNFSKN_D &#160;$">
# <polygon fill="#63b8ff" stroke="black" points="244.85,-276.5 39.75,-276.5 39.75,-240.5 244.85,-240.5 244.85,-276.5"/>
# <g id="a_node5_5"><a xlink:title="Exports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEEXPGNFSKN = (PAKNEEXPGNFSKN(&#45;1)*EXP(PAKNEEXPGNFSKN_A+ (&#45;0.35*(LOG(PAKNEEXPGNFSKN(&#45;1))&#45;LOG(PAKXMKT(&#45;1))&#45;0.6*LOG(PAKNEEXPGNFSXN(&#45;1)/(PAKNYGDPFCSTXN(&#45;1))))+1*((LOG(PAKXMKT))&#45;(LOG(PAKXMK

# %% [markdown]
# #### The graph (network) can be pruned to show only variables with a max impact higher than a certain threshold

# %%
mpak.PAKNYGDPMKTPKN.tracepre(filte=20 )
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.1.2 (0)
#  -->
# <!-- Title: TD Pages: 1 -->
# <svg width="432pt" height="408pt"
#  viewBox="0.00 0.00 432.00 408.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.815171 0.815171) rotate(0) translate(4 496.5)">
# <title>TD</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-496.5 525.95,-496.5 525.95,4 -4,4"/>
# <text xml:space="preserve" text-anchor="middle" x="260.98" y="-7.2" font-family="Times New Roman,serif" font-size="14.00">PAKNYGDPMKTPKN</text>
# <!-- PAKNECONGOVTKN -->
# <g id="node1" class="node">
# <title>PAKNECONGOVTKN</title>
# <g id="a_node1"><a xlink:title="Gov. Cons real&#10;FRML &lt;IDENT&gt; PAKNECONGOVTKN = PAKNECONGOVTCN/PAKNECONGOVTXN $">
# <polygon fill="#63b8ff" stroke="black" points="255.73,-492.5 28.88,-492.5 28.88,-456.5 255.73,-456.5 255.73,-492.5"/>
# <g id="a_node1_0"><a xlink:title="Gov. Cons real&#10;FRML &lt;IDENT&gt; PAKNECONGOVTKN = PAKNECONGOVTCN/PAKNECONGOVTXN $">
# <text xml:space="preserve" text-anchor="start" x="34.68" y="-469.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNECONGOVTKN:Gov. Cons real</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNYGDPMKTPKN -->
# <g id="node7" class="node">
# <title>PAKNYGDPMKTPKN</title>
# <g id="a_node7"><a xlink:title="Real GDP&#10;FRML &lt;IDENT&gt; PAKNYGDPMKTPKN = PAKNECONPRVTKN+PAKNECONGOVTKN+PAKNEGDIFTOTKN+PAKNEGDISTKBKN+PAKNEEXPGNFSKN&#45;PAKNEIMPGNFSKN+PAKNYGDPDISCKN+PAKADAP*PAKDISPREPKN $">
# <polygon fill="red" stroke="black" points="521.95,-276.5 320.6,-276.5 320.6,-240.5 521.95,-240.5 521.95,-276.5"/>
# <g id="a_node7_1"><a xlink:title="Real GDP&#10;FRML &lt;IDENT&gt; PAKNYGDPMKTPKN = PAKNECONPRVTKN+PAKNECONGOVTKN+PAKNEGDIFTOTKN+PAKNEGDISTKBKN+PAKNEEXPGNFSKN&#45;PAKNEIMPGNFSKN+PAKNYGDPDISCKN+PAKADAP*PAKDISPREPKN $">
# <text xml:space="preserve" text-anchor="start" x="326.4" y="-253.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNYGDPMKTPKN:Real GDP</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNECONGOVTKN&#45;&gt;PAKNYGDPMKTPKN -->
# <g id="edge4" class="edge">
# <title>PAKNECONGOVTKN&#45;&gt;PAKNYGDPMKTPKN</title>
# <g id="a_edge4"><a xlink:href="bogus" xlink:title=" PAKNECONGOVTKN &#45;&gt; PAKNYGDPMKTPKN Min. att. 0% &#160;max: 2223%">
# <path fill="none" stroke="black" stroke-width="8" d="M255.91,-461.28C266.02,-457.67 275.76,-453.15 284.6,-447.5 344.08,-409.5 385.57,-335.32 405.92,-292.05"/>
# <polygon fill="black" stroke="black" stroke-width="8" points="412.17,-295.22 409.92,-283.22 399.42,-289.45 412.17,-295.22"/>
# </a>
# </g>
# </g>
# <!-- PAKADAP -->
# <g id="node2" class="node">
# <title>PAKADAP</title>
# <g id="a_node2"><a xlink:title="PAKADAP&#10;Exogen">
# <polygon fill="yellow" stroke="black" points="181.48,-438.5 103.13,-438.5 103.13,-402.5 181.48,-402.5 181.48,-438.5"/>
# <g id="a_node2_2"><a xlink:title="PAKADAP&#10;Exogen">
# <text xml:space="preserve" text-anchor="start" x="108.93" y="-415.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKADAP:</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKADAP&#45;&gt;PAKNYGDPMKTPKN -->
# <g id="edge8" class="edge">
# <title>PAKADAP&#45;&gt;PAKNYGDPMKTPKN</title>
# <g id="a_edge8"><a xlink:href="bogus" xlink:title=" PAKADAP &#45;&gt; PAKNYGDPMKTPKN Min. att. 0% &#160;max: 0%">
# <path fill="none" stroke="black" d="M181.9,-419.21C211.5,-416.83 252.58,-410.41 284.6,-393.5 334.13,-367.34 377.26,-317.1 400.94,-285.83"/>
# <polygon fill="black" stroke="black" points="403.6,-288.12 406.75,-278 397.98,-283.95 403.6,-288.12"/>
# </a>
# </g>
# </g>
# <!-- PAKNYGDPDISCKN -->
# <g id="node3" class="node">
# <title>PAKNYGDPDISCKN</title>
# <g id="a_node3"><a xlink:title="GDP Disc., 2000 LCU mn&#10;Exogen">
# <polygon fill="yellow" stroke="black" points="284.6,-384.5 0,-384.5 0,-348.5 284.6,-348.5 284.6,-384.5"/>
# <g id="a_node3_3"><a xlink:title="GDP Disc., 2000 LCU mn&#10;Exogen">
# <text xml:space="preserve" text-anchor="start" x="5.8" y="-361.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNYGDPDISCKN:GDP Disc., 2000 LCU mn</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNYGDPDISCKN&#45;&gt;PAKNYGDPMKTPKN -->
# <g id="edge1" class="edge">
# <title>PAKNYGDPDISCKN&#45;&gt;PAKNYGDPMKTPKN</title>
# <g id="a_edge1"><a xlink:href="bogus" xlink:title=" PAKNYGDPDISCKN &#45;&gt; PAKNYGDPMKTPKN Min. att. 0% &#160;max: 0%">
# <path fill="none" stroke="black" d="M258.38,-348.03C267.36,-345.53 276.2,-342.7 284.6,-339.5 321.59,-325.43 359.99,-301.49 386.45,-283.27"/>
# <polygon fill="black" stroke="black" points="388.2,-286.32 394.39,-277.72 384.19,-280.58 388.2,-286.32"/>
# </a>
# </g>
# </g>
# <!-- PAKNEIMPGNFSKN -->
# <g id="node4" class="node">
# <title>PAKNEIMPGNFSKN</title>
# <g id="a_node4"><a xlink:title="Imports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEIMPGNFSKN = (PAKNEIMPGNFSKN(&#45;1)*EXP(PAKNEIMPGNFSKN_A+ (&#45;0.324143718656754*(LOG(PAKNEIMPGNFSKN(&#45;1))&#45;LOG(PAKNEGDETTOTKN(&#45;1))+0.8*LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1)))&#45;0.583459272245018+1*((LOG(PAKNEGDETTOTKN))&#45;(LOG(PAKNEGDETTOTKN(&#45;1))))&#45;0.0921874580409631*((LOG(PAKNEIMPGNFSXN/PAKNYGDPFCSTXN))&#45;(LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1))))&#45;0.0361746331863615*DURING_2012) )) * (1&#45;PAKNEIMPGNFSKN_D)+ PAKNEIMPGNFSKN_X*PAKNEIMPGNFSKN_D &#160;$">
# <polygon fill="#63b8ff" stroke="black" points="244.85,-330.5 39.75,-330.5 39.75,-294.5 244.85,-294.5 244.85,-330.5"/>
# <g id="a_node4_4"><a xlink:title="Imports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEIMPGNFSKN = (PAKNEIMPGNFSKN(&#45;1)*EXP(PAKNEIMPGNFSKN_A+ (&#45;0.324143718656754*(LOG(PAKNEIMPGNFSKN(&#45;1))&#45;LOG(PAKNEGDETTOTKN(&#45;1))+0.8*LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1)))&#45;0.583459272245018+1*((LOG(PAKNEGDETTOTKN))&#45;(LOG(PAKNEGDETTOTKN(&#45;1))))&#45;0.0921874580409631*((LOG(PAKNEIMPGNFSXN/PAKNYGDPFCSTXN))&#45;(LOG(PAKNEIMPGNFSXN(&#45;1)/PAKNYGDPFCSTXN(&#45;1))))&#45;0.0361746331863615*DURING_2012) )) * (1&#45;PAKNEIMPGNFSKN_D)+ PAKNEIMPGNFSKN_X*PAKNEIMPGNFSKN_D &#160;$">
# <text xml:space="preserve" text-anchor="start" x="45.55" y="-307.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNEIMPGNFSKN:Imports real</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNEIMPGNFSKN&#45;&gt;PAKNYGDPMKTPKN -->
# <g id="edge5" class="edge">
# <title>PAKNEIMPGNFSKN&#45;&gt;PAKNYGDPMKTPKN</title>
# <g id="a_edge5"><a xlink:href="bogus" xlink:title=" PAKNEIMPGNFSKN &#45;&gt; PAKNYGDPMKTPKN Min. att. &#45;56% &#160;max: 2561%">
# <path fill="none" stroke="black" stroke-width="8" d="M240.61,-294.01C255.35,-291.18 270.38,-288.27 284.6,-285.5 293.37,-283.79 302.45,-282.01 311.57,-280.21"/>
# <polygon fill="black" stroke="black" stroke-width="8" points="312.68,-287.13 321.13,-278.32 309.96,-273.39 312.68,-287.13"/>
# </a>
# </g>
# </g>
# <!-- PAKNEEXPGNFSKN -->
# <g id="node5" class="node">
# <title>PAKNEEXPGNFSKN</title>
# <g id="a_node5"><a xlink:title="Exports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEEXPGNFSKN = (PAKNEEXPGNFSKN(&#45;1)*EXP(PAKNEEXPGNFSKN_A+ (&#45;0.35*(LOG(PAKNEEXPGNFSKN(&#45;1))&#45;LOG(PAKXMKT(&#45;1))&#45;0.6*LOG(PAKNEEXPGNFSXN(&#45;1)/(PAKNYGDPFCSTXN(&#45;1))))+1*((LOG(PAKXMKT))&#45;(LOG(PAKXMKT(&#45;1))))+0.3*((LOG(PAKNEEXPGNFSXN/(PAKNYGDPFCSTXN)))&#45;(LOG(PAKNEEXPGNFSXN(&#45;1)/(PAKNYGDPFCSTXN(&#45;1)))))+4.38465374402991&#45;0.237469889780178*DURING_1999&#45;0.230689812873392*DURING_1998+0.320967524344658*DURING_1991+0.250252413901575*DURING_1986) )) * (1&#45;PAKNEEXPGNFSKN_D)+ PAKNEEXPGNFSKN_X*PAKNEEXPGNFSKN_D &#160;$">
# <polygon fill="#63b8ff" stroke="black" points="244.85,-276.5 39.75,-276.5 39.75,-240.5 244.85,-240.5 244.85,-276.5"/>
# <g id="a_node5_5"><a xlink:title="Exports real&#10;FRML &lt;DAMP,STOC&gt; PAKNEEXPGNFSKN = (PAKNEEXPGNFSKN(&#45;1)*EXP(PAKNEEXPGNFSKN_A+ (&#45;0.35*(LOG(PAKNEEXPGNFSKN(&#45;1))&#45;LOG(PAKXMKT(&#45;1))&#45;0.6*LOG(PAKNEEXPGNFSXN(&#45;1)/(PAKNYGDPFCSTXN(&#45;1))))+1*((LOG(PAKXMKT))&#45;(LOG(PAKXMK

# %% [markdown]
# #### and we can go several levels upstream
# The filter=20 prunes the graph as it can be large

# %%
mpak.PAKNYGDPMKTPKN.tracepre(filter=20,up=2)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 14.1.2 (0)
#  -->
# <!-- Title: TD Pages: 1 -->
# <svg width="432pt" height="243pt"
#  viewBox="0.00 0.00 432.00 243.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(0.438668 0.438668) rotate(0) translate(4 550.5)">
# <title>TD</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-550.5 980.8,-550.5 980.8,4 -4,4"/>
# <text xml:space="preserve" text-anchor="middle" x="488.4" y="-7.2" font-family="Times New Roman,serif" font-size="14.00">PAKNYGDPMKTPKN</text>
# <!-- PAKNYYWBTOTLCN -->
# <g id="node1" class="node">
# <title>PAKNYYWBTOTLCN</title>
# <g id="a_node1"><a xlink:title="Total Wage Bill&#10;FRML &lt;IDENT&gt; PAKNYYWBTOTLCN = PAKNYWRTTOTLCN*PAKLMEMPTOTLCN $">
# <polygon fill="#63b8ff" stroke="black" points="354.35,-546.5 122.25,-546.5 122.25,-510.5 354.35,-510.5 354.35,-546.5"/>
# <g id="a_node1_0"><a xlink:title="Total Wage Bill&#10;FRML &lt;IDENT&gt; PAKNYYWBTOTLCN = PAKNYWRTTOTLCN*PAKLMEMPTOTLCN $">
# <text xml:space="preserve" text-anchor="start" x="128.05" y="-523.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNYYWBTOTLCN:Total Wage Bill</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNECONPRVTKN -->
# <g id="node9" class="node">
# <title>PAKNECONPRVTKN</title>
# <g id="a_node9"><a xlink:title="HH. Cons Real&#10;FRML &lt;DAMP,STOC&gt; PAKNECONPRVTKN = (PAKNECONPRVTKN(&#45;1)*EXP(PAKNECONPRVTKN_A+ (&#45;0.2*(LOG(PAKNECONPRVTKN(&#45;1))&#45;LOG(1.21203101101442)&#45;LOG((((PAKBXFSTREMTCD(&#45;1)&#45;PAKBMFSTREMTCD(&#45;1))*PAKPANUSATLS(&#45;1))+PAKGGEXPTRNSCN(&#45;1)+PAKNYYWBTOTLCN(&#45;1)*(1&#45;PAKGGREVDRCTXN(&#45;1)/100))/PAKNECONPRVTXN(&#45;1)))+0.763938860758873*((LOG((((PAKBXFSTREMTCD&#45;PAKBMFSTREMTCD)*PAKPANUSATLS)+PAKGGEXPTRNSCN+PAKNYYWBTOTLCN*(1&#45;PAKGGREVDRCTXN/100))/PAKNECONPRVTXN))&#45;(LOG((((PAKBXFSTREMTCD(&#45;1)&#45;PAKBMFSTREMTCD(&#45;1))*PAKPANUSATLS(&#45;1))+PAKGGEXPTRNSCN(&#45;1)+PAKNYYWBTOTLCN(&#45;1)*(1&#45;PAKGGREVDRCTXN(&#45;1)/100))/PAKNECONPRVTXN(&#45;1))))&#45;0.0634474791568939*DURING_2009&#45;0.3*(PAKFMLBLPOLYXN/100&#45;((LOG(PAKNECONPRVTXN))&#45;(LOG(PAKNECONPRVTXN(&#45;1)))))) )) * (1&#45;PAKNECONPRVTKN_D)+ PAKNECONPRVTKN_X*PAKNECONPRVTKN_D &#160;$">
# <polygon fill="#63b8ff" stroke="black" points="738.33,-492.5 513.72,-492.5 513.72,-456.5 738.33,-456.5 738.33,-492.5"/>
# <g id="a_node9_1"><a xlink:title="HH. Cons Real&#10;FRML &lt;DAMP,STOC&gt; PAKNECONPRVTKN = (PAKNECONPRVTKN(&#45;1)*EXP(PAKNECONPRVTKN_A+ (&#45;0.2*(LOG(PAKNECONPRVTKN(&#45;1))&#45;LOG(1.21203101101442)&#45;LOG((((PAKBXFSTREMTCD(&#45;1)&#45;PAKBMFSTREMTCD(&#45;1))*PAKPANUSATLS(&#45;1))+PAKGGEXPTRNSCN(&#45;1)+PAKNYYWBTOTLCN(&#45;1)*(1&#45;PAKGGREVDRCTXN(&#45;1)/100))/PAKNECONPRVTXN(&#45;1)))+0.763938860758873*((LOG((((PAKBXFSTREMTCD&#45;PAKBMFSTREMTCD)*PAKPANUSATLS)+PAKGGEXPTRNSCN+PAKNYYWBTOTLCN*(1&#45;PAKGGREVDRCTXN/100))/PAKNECONPRVTXN))&#45;(LOG((((PAKBXFSTREMTCD(&#45;1)&#45;PAKBMFSTREMTCD(&#45;1))*PAKPANUSATLS(&#45;1))+PAKGGEXPTRNSCN(&#45;1)+PAKNYYWBTOTLCN(&#45;1)*(1&#45;PAKGGREVDRCTXN(&#45;1)/100))/PAKNECONPRVTXN(&#45;1))))&#45;0.0634474791568939*DURING_2009&#45;0.3*(PAKFMLBLPOLYXN/100&#45;((LOG(PAKNECONPRVTXN))&#45;(LOG(PAKNECONPRVTXN(&#45;1)))))) )) * (1&#45;PAKNECONPRVTKN_D)+ PAKNECONPRVTKN_X*PAKNECONPRVTKN_D &#160;$">
# <text xml:space="preserve" text-anchor="start" x="519.52" y="-469.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNECONPRVTKN:HH. Cons Real</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNYYWBTOTLCN&#45;&gt;PAKNECONPRVTKN -->
# <g id="edge3" class="edge">
# <title>PAKNYYWBTOTLCN&#45;&gt;PAKNECONPRVTKN</title>
# <g id="a_edge3"><a xlink:href="bogus" xlink:title=" PAKNYYWBTOTLCN &#45;&gt; PAKNECONPRVTKN Min. att. &#45;112% &#160;max: 58%">
# <path fill="none" stroke="black" stroke-width="8" d="M354.77,-516.92C393.56,-512.62 437.02,-507.35 476.6,-501.5 488.27,-499.78 500.42,-497.82 512.53,-495.78"/>
# <polygon fill="black" stroke="black" stroke-width="8" points="513.43,-502.73 522.1,-494.13 511.05,-488.93 513.43,-502.73"/>
# </a>
# </g>
# </g>
# <!-- PAKNECONGOVTKN -->
# <g id="node2" class="node">
# <title>PAKNECONGOVTKN</title>
# <g id="a_node2"><a xlink:title="Gov. Cons real&#10;FRML &lt;IDENT&gt; PAKNECONGOVTKN = PAKNECONGOVTCN/PAKNECONGOVTXN $">
# <polygon fill="#63b8ff" stroke="black" points="739.45,-384.5 512.6,-384.5 512.6,-348.5 739.45,-348.5 739.45,-384.5"/>
# <g id="a_node2_2"><a xlink:title="Gov. Cons real&#10;FRML &lt;IDENT&gt; PAKNECONGOVTKN = PAKNECONGOVTCN/PAKNECONGOVTXN $">
# <text xml:space="preserve" text-anchor="start" x="518.4" y="-361.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNECONGOVTKN:Gov. Cons real</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNYGDPMKTPKN -->
# <g id="node14" class="node">
# <title>PAKNYGDPMKTPKN</title>
# <g id="a_node14"><a xlink:title="Real GDP&#10;FRML &lt;IDENT&gt; PAKNYGDPMKTPKN = PAKNECONPRVTKN+PAKNECONGOVTKN+PAKNEGDIFTOTKN+PAKNEGDISTKBKN+PAKNEEXPGNFSKN&#45;PAKNEIMPGNFSKN+PAKNYGDPDISCKN+PAKADAP*PAKDISPREPKN $">
# <polygon fill="red" stroke="black" points="976.8,-276.5 775.45,-276.5 775.45,-240.5 976.8,-240.5 976.8,-276.5"/>
# <g id="a_node14_3"><a xlink:title="Real GDP&#10;FRML &lt;IDENT&gt; PAKNYGDPMKTPKN = PAKNECONPRVTKN+PAKNECONGOVTKN+PAKNEGDIFTOTKN+PAKNEGDISTKBKN+PAKNEEXPGNFSKN&#45;PAKNEIMPGNFSKN+PAKNYGDPDISCKN+PAKADAP*PAKDISPREPKN $">
# <text xml:space="preserve" text-anchor="start" x="781.25" y="-253.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNYGDPMKTPKN:Real GDP</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNECONGOVTKN&#45;&gt;PAKNYGDPMKTPKN -->
# <g id="edge4" class="edge">
# <title>PAKNECONGOVTKN&#45;&gt;PAKNYGDPMKTPKN</title>
# <g id="a_edge4"><a xlink:href="bogus" xlink:title=" PAKNECONGOVTKN &#45;&gt; PAKNYGDPMKTPKN Min. att. 0% &#160;max: 2223%">
# <path fill="none" stroke="black" stroke-width="8" d="M669.39,-348.06C710.16,-330.31 772.11,-303.34 817.38,-283.64"/>
# <polygon fill="black" stroke="black" stroke-width="8" points="820.16,-290.06 826.54,-279.65 814.57,-277.22 820.16,-290.06"/>
# </a>
# </g>
# </g>
# <!-- PAKNECONGOVTXN -->
# <g id="node3" class="node">
# <title>PAKNECONGOVTXN</title>
# <g id="a_node3"><a xlink:title="Implicit LCU defl., Govt. Cons., 2000 = 1&#10;FRML &lt;DAMP,STOC&gt; PAKNECONGOVTXN = (PAKNECONGOVTXN(&#45;1)*EXP(PAKNECONGOVTXN_A+ (&#45;0.3*(LOG(PAKNECONGOVTXN(&#45;1))&#45;LOG(PAKNECONPRVTXN(&#45;1)))+0.0752362082122748+0.5*((LOG(PAKNECONGOVTXN(&#45;1)))&#45;(LOG(PAKNECONGOVTXN(&#45;2))))+(1&#45;0.5)*((LOG(PAKNECONPRVTXN))&#45;(LOG(PAKNECONPRVTXN(&#45;1))))) )) * (1&#45;PAKNECONGOVTXN_D)+ PAKNECONGOVTXN_X*PAKNECONGOVTXN_D &#160;$">
# <polygon fill="#63b8ff" stroke="black" points="427.47,-438.5 49.12,-438.5 49.12,-402.5 427.47,-402.5 427.47,-438.5"/>
# <g id="a_node3_4"><a xlink:title="Implicit LCU defl., Govt. Cons., 2000 = 1&#10;FRML &lt;DAMP,STOC&gt; PAKNECONGOVTXN = (PAKNECONGOVTXN(&#45;1)*EXP(PAKNECONGOVTXN_A+ (&#45;0.3*(LOG(PAKNECONGOVTXN(&#45;1))&#45;LOG(PAKNECONPRVTXN(&#45;1)))+0.0752362082122748+0.5*((LOG(PAKNECONGOVTXN(&#45;1)))&#45;(LOG(PAKNECONGOVTXN(&#45;2))))+(1&#45;0.5)*((LOG(PAKNECONPRVTXN))&#45;(LOG(PAKNECONPRVTXN(&#45;1))))) )) * (1&#45;PAKNECONGOVTXN_D)+ PAKNECONGOVTXN_X*PAKNECONGOVTXN_D &#160;$">
# <text xml:space="preserve" text-anchor="start" x="54.92" y="-415.45" font-family="Times New Roman,serif" font-size="14.00" fill="blue">PAKNECONGOVTXN:Implicit LCU defl., Govt. Cons., 2000 = 1</text>
# </a>
# </g>
# </a>
# </g>
# </g>
# <!-- PAKNECONGOVTXN&#45;&gt;PAKNECONGOVTKN -->
# <g id="edge10" class="edge">
# <title>PAKNECONGOVTXN&#45;&gt;PAKNECONGOVTKN</title>
# <g id="a_edge10"><a xlink:href="bogus" xlink:title=" PAKNECONGOVTXN &#45;&gt; PAKNECONGOVTKN Min. att. &#45;77% &#160;max: 0%">
# <path fill="none" stroke="black" stroke-width="7.74" d="M413.46,-402.03C434.76,-399.38 456.19,-396.51 476.6,-393.5 488.27,-391.78 500.42,-389.82 512.53,-387.78"/>
# <polygon fill="black" stroke="bla

# %% [markdown]
# ### Attribution
# Try select different years

# %%
mpak.get_dekom_gui('PAKNYGDPMKTPKN')
# Out:
# interactive(children=(Dropdown(description='Variable', index=321, options=('CHNEXR05', 'CHNPCEXN05', 'DEUEXR05…

# %% [markdown]
# ## Try some of the other notebooks in this example
# Below a list of  notebooks which can be started by clicking.

# %%
mpak.display_toc_this()
# Out:
# **Jupyter notebooks**
# &nbsp; &nbsp; <a href="model specification.ipynb" target="_blank">model specification</a>
# &nbsp; &nbsp; <a href="modelflow_stability_examples.ipynb" target="_blank">modelflow_stability_examples</a>
# &nbsp; &nbsp; <a href="oldstart.ipynb" target="_blank">oldstart</a>
# &nbsp; &nbsp; <a href="start.ipynb" target="_blank">start</a>
